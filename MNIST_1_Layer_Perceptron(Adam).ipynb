# %% [markdown]
# # Init

# %%
# Execute this code block to install dependencies when running on colab
try:
    import torch
except:
    from os.path import exists
    from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
    platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
    cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
    accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

    # !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-1.0.0-{platform}-linux_x86_64.whl torchvision

try: 
    import torchbearer
except:
    # !pip install torchbearer
# Out:
# Collecting torchbearer
#   Downloading https://files.pythonhosted.org/packages/ff/e9/4049a47dd2e5b6346a2c5d215b0c67dce814afbab1cd54ce024533c4834e/torchbearer-0.5.3-py3-none-any.whl (138kB)
#      |████████████████████████████████| 143kB 2.7MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchbearer) (1.18.4)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from torchbearer) (1.5.0+cu101)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from torchbearer) (4.41.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.0.0->torchbearer) (0.16.0)
# Installing collected packages: torchbearer
# Successfully installed torchbearer-0.5.3

# %% [markdown]
# # Prepare MNIST dataset

# %%
# automatically reload external modules if they change
# %load_ext autoreload
# %autoreload 2

import torch
import torch.nn.functional as F
import torchvision.transforms as transforms
import torchbearer
from torch import nn
from torch import optim
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchbearer import Trial
import pandas as pd
import matplotlib.pyplot as plt

# %%
# fix random seed for reproducibility
seed = 7
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True

# %%
# flatten 28*28 images to a 784 vector for each image
transform = transforms.Compose([
    transforms.ToTensor(),  # convert to tensor
    transforms.Lambda(lambda x: x.view(-1))  # flatten into vector
])

# load data
trainset = MNIST(".", train=True, download=True, transform=transform)
testset = MNIST(".", train=False, download=True, transform=transform)

# create data loaders
trainloader = DataLoader(trainset, batch_size=128, shuffle=True)
testloader = DataLoader(testset, batch_size=128, shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw
# Processing...
# Done!
# /pytorch/torch/csrc/utils/tensor_numpy.cpp:141: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program.

# %% [markdown]
# # Load Model

# %%
# define baseline model
class Perceptron(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(Perceptron, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size) 
        self.fc2 = nn.Linear(hidden_size, num_classes)  
    
    def forward(self, x):
        out = self.fc1(x)
        out = F.relu(out)
        out = self.fc2(out)
        if not self.training:
            out = F.softmax(out, dim=1)
        return out

# %%
# build the model
device = "cuda:0" if torch.cuda.is_available() else "cpu"
# model = Perceptron(784, 784, 10).to(device)

from torchbearer.callbacks import StepLR
from torchbearer.callbacks.decorators import on_end_epoch

# def reduce_rate(state):
#   print(optimiser.lear)
sch = StepLR(step_size=75, gamma=0.1)

# %% [markdown]
# Train and test

# %%
# %%time
# build the model
model = Perceptron(784, 784, 10).to(device)

# define the loss function and the optimiser
loss_function = nn.CrossEntropyLoss()
optimiser = optim.Adam(model.parameters())

device = "cuda:0" if torch.cuda.is_available() else "cpu"
# trial = Trial(model, optimiser, loss_function, metrics=['loss', 'accuracy']).to(device)
trial = Trial(model, optimiser, loss_function,callbacks=[sch], metrics=['loss', 'accuracy','lr']).to(device)
trial.with_generators(trainloader, val_generator=testloader)
history = trial.run(epochs=100)

results = trial.evaluate(data_key=torchbearer.TEST_DATA)
print(results)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='0/100(t)', max=469.0, style=ProgressStyle(description_wid…
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:123: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:143: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# HBox(children=(FloatProgress(value=0.0, description='0/100(v)', max=79.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='1/100(t)', max=469.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='1/100(v)', max=79.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='2/100(t)', max=469.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='2/100(v)', max=79.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='3/100(t)', max=469.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='3/100(v)', max=79.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='4/100(t)', max=469.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='4/100(v)', max=79.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='5/100(t)', max=469.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='5/100(v)', max=79.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='6/100(t)', max=469.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='6/100(v)', max=79.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='7/100(t)', max=469.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='7/100(v)', max=79.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='8/100(t)', max=469.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='8/100(v)', max=79.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='9/100(t)', max=469.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='9/100(v)', max=79.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='10/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='10/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='11/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='11/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='12/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='12/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='13/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='13/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='14/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='14/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='15/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='15/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='16/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='16/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='17/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='17/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='18/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='18/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='19/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='19/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='20/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='20/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='21/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='21/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='22/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='22/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='23/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='23/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='24/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='24/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='25/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='25/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='26/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='26/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='27/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='27/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='28/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='28/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='29/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='29/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='30/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='30/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='31/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='31/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='32/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='32/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='33/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='33/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='34/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='34/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='35/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='35/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='36/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='36/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='37/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='37/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='38/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='38/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='39/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='39/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='40/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='40/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='41/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='41/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='42/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='42/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='43/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='43/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='44/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='44/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='45/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='45/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='46/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='46/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='47/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='47/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='48/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='48/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='49/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='49/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='50/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='50/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='51/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='51/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='52/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='52/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='53/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='53/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='54/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='54/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='55/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='55/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='56/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='56/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='57/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='57/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='58/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='58/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='59/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='59/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='60/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='60/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='61/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='61/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='62/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='62/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='63/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='63/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='64/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='64/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='65/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='65/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='66/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='66/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='67/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='67/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='68/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='68/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='69/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='69/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='70/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='70/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='71/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='71/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='72/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='72/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='73/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='73/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='74/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='74/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='75/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='75/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='76/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='76/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='77/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='77/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='78/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='78/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='79/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='79/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='80/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='80/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='81/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='81/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='82/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='82/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='83/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='83/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='84/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='84/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='85/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='85/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='86/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='86/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='87/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='87/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='88/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='88/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='89/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='89/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='90/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='90/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='91/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='91/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='92/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='92/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='93/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='93/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='94/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='94/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='95/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='95/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='96/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='96/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='97/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='97/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='98/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='98/100(v)', max=79.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='99/100(t)', max=469.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='99/100(v)', max=79.0, style=ProgressStyle(description_wid…
# {}
# CPU times: user 19min 14s, sys: 39.1 s, total: 19min 53s
# Wall time: 21min 31s

# %%
def get_data(history,name):
  train_acc = [x['acc'] for x in history]
  train_loss = [x['loss'] for x in history]
  test_acc = [x['val_acc'] for x in history]
  test_loss = [x['val_loss'] for x in history]
  frame = pd.DataFrame(zip(train_acc,train_loss,test_acc,test_loss))
  frame.columns = ['train_acc','train_loss','val_acc','val_loss']
  frame.to_csv(name)
  return frame

# %%
frame = get_data(history,'MLP(Adam).csv')

# %%
plt.figure(figsize=(10,6))
plt.title('Adam default lr, 90 epochs, reduce lr on plateau on 75 epoch')
plt.plot(range(100),frame['train_acc'])
plt.plot(range(100),frame['val_acc'])

plt.figure(figsize=(10,6))
plt.title('Adam default lr, 90 epochs, reduce lr on plateau on 75 epoch')
plt.plot(range(100),frame['train_loss'])
plt.plot(range(100),frame['val_loss'])
